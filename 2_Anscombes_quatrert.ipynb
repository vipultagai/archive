# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_json("/content/sample_data/anscombe.json")

# %%
data.head()
# Out:
#   Series   X     Y
# 0      I  10  8.04
# 1      I   8  6.95
# 2      I  13  7.58
# 3      I   9  8.81
# 4      I  11  8.33

# %%
one = data[data['Series']=="I"].drop("Series",axis = 1)
two = data[data['Series']=="II"].drop("Series",axis = 1)
three = data[data['Series']=="III"].drop("Series",axis = 1)
four = data[data['Series']=="IV"].drop("Series",axis = 1)

# %%
one_Y = one['Y'].mean()
two_Y = two['Y'].mean()
three_Y = three['Y'].mean()
four_Y = four['Y'].mean()
print(one_Y,two_Y,three_Y,four_Y)
# Out:
# 7.5 7.500909090909091 7.500000000000001 7.50090909090909

# %%
one_Y = one['Y'].mean()
two_Y = two['Y'].mean()
three_Y = three['Y'].mean()
four_Y = four['Y'].mean()
print(one_Y,two_Y,three_Y,four_Y)

# %%
plt.plot(one['X'],one['Y'],'*')

# %%
plt.plot(two['X'],two['Y'],'*')

# %%
plt.plot(three['X'],three['Y'],'*')

# %%
plt.plot(four['X'],four['Y'],'*')
